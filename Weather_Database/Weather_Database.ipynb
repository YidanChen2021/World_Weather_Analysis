# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longtitude combinations.
lats = np.random.uniform(-90.000, 90.000, size = 2000)
lngs = np.random.uniform(-180.000, 180.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 777

# %%
# Import the requests library.
import requests

# Import the api key
from config import weather_api_key

#Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nouakchott
# Processing Record 2 of Set 1 | yaan
# Processing Record 3 of Set 1 | potosi
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 1 | kazerun
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | new norfolk
# Processing Record 9 of Set 1 | atuona
# Processing Record 10 of Set 1 | chokwe
# Processing Record 11 of Set 1 | mehamn
# Processing Record 12 of Set 1 | pacific grove
# Processing Record 13 of Set 1 | nurobod
# Processing Record 14 of Set 1 | upernavik
# Processing Record 15 of Set 1 | ribeira grande
# Processing Record 16 of Set 1 | ponta do sol
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | honiara
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | klaksvik
# Processing Record 21 of Set 1 | tigil
# Processing Record 22 of Set 1 | guerrero negro
# Processing Record 23 of Set 1 | hilo
# Processing Record 24 of Set 1 | clyde river
# Processing Record 25 of Set 1 | alofi
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | taonan
# Processing Record 28 of Set 1 | bengkulu
# Processing Record 29 of Set 1 | kayes
# Processing Record 30 of Set 1 | urucara
# Processing Record 31 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 1 | coihaique
# Processing Record 33 of Set 1 | lebu
# Processing Record 34 of Set 1 | tapaua
# City not found. Skipping...
# Processing Record 35 of Set 1 | ilulissat
# Processing Record 36 of Set 1 | neiafu
# Processing Record 37 of Set 1 | kapaa
# Processing Record 38 of Set 1 | arraial do cabo
# Processing Record 39 of Set 1 | naze
# Processing Record 40 of Set 1 | karratha
# Processing Record 41 of Set 1 | codrington
# Processing Record 42 of Set 1 | letlhakane
# Processing Record 43 of Set 1 | puerto ayora
# Processing Record 44 of Set 1 | rikitea
# Processing Record 45 of Set 1 | cherdyn
# Processing Record 46 of Set 1 | iacu
# Processing Record 47 of Set 1 | boqueirao
# Processing Record 48 of Set 1 | gat
# Processing Record 49 of Set 1 | lata
# Processing Record 50 of Set 1 | nanortalik
# Processing Record 1 of Set 2 | mar del plata
# Processing Record 2 of Set 2 | vila franca do campo
# Processing Record 3 of Set 2 | lashio
# Processing Record 4 of Set 2 | imbituba
# Processing Record 5 of Set 2 | vriezenveen
# Processing Record 6 of Set 2 | melito di porto salvo
# Processing Record 7 of Set 2 | chuy
# Processing Record 8 of Set 2 | yellowknife
# Processing Record 9 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 2 | east london
# Processing Record 11 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 12 of Set 2 | saldanha
# Processing Record 13 of Set 2 | berezovyy
# Processing Record 14 of Set 2 | saint-philippe
# Processing Record 15 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 2 | ajaccio
# Processing Record 17 of Set 2 | defiance
# Processing Record 18 of Set 2 | valle de banderas
# Processing Record 19 of Set 2 | cabo san lucas
# Processing Record 20 of Set 2 | butaritari
# Processing Record 21 of Set 2 | vestmannaeyjar
# Processing Record 22 of Set 2 | mound
# Processing Record 23 of Set 2 | monteria
# Processing Record 24 of Set 2 | bluff
# Processing Record 25 of Set 2 | serchhip
# Processing Record 26 of Set 2 | port alfred
# Processing Record 27 of Set 2 | korla
# Processing Record 28 of Set 2 | khatanga
# Processing Record 29 of Set 2 | vaini
# Processing Record 30 of Set 2 | hobart
# Processing Record 31 of Set 2 | flagstaff
# Processing Record 32 of Set 2 | tessalit
# Processing Record 33 of Set 2 | scunthorpe
# Processing Record 34 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 2 | dikson
# Processing Record 36 of Set 2 | kodiak
# Processing Record 37 of Set 2 | hithadhoo
# Processing Record 38 of Set 2 | caravelas
# Processing Record 39 of Set 2 | faanui
# Processing Record 40 of Set 2 | sitka
# Processing Record 41 of Set 2 | tapejara
# Processing Record 42 of Set 2 | severo-kurilsk
# Processing Record 43 of Set 2 | tuktoyaktuk
# Processing Record 44 of Set 2 | sungaipenuh
# Processing Record 45 of Set 2 | avarua
# Processing Record 46 of Set 2 | batagay-alyta
# Processing Record 47 of Set 2 | lompoc
# Processing Record 48 of Set 2 | kaniama
# Processing Record 49 of Set 2 | alyangula
# Processing Record 50 of Set 2 | qurayyat
# Processing Record 1 of Set 3 | trairi
# Processing Record 2 of Set 3 | ust-maya
# Processing Record 3 of Set 3 | castro
# Processing Record 4 of Set 3 | mount gambier
# Processing Record 5 of Set 3 | trancoso
# Processing Record 6 of Set 3 | albany
# Processing Record 7 of Set 3 | rath
# Processing Record 8 of Set 3 | bambous virieux
# Processing Record 9 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 3 | hamilton
# Processing Record 11 of Set 3 | touros
# Processing Record 12 of Set 3 | homer
# Processing Record 13 of Set 3 | chokurdakh
# Processing Record 14 of Set 3 | tuy hoa
# Processing Record 15 of Set 3 | cidreira
# Processing Record 16 of Set 3 | ardmore
# Processing Record 17 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 3 | lac du bonnet
# Processing Record 19 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 3 | shimoda
# Processing Record 21 of Set 3 | soyo
# Processing Record 22 of Set 3 | cherskiy
# Processing Record 23 of Set 3 | taoudenni
# Processing Record 24 of Set 3 | morrinhos
# Processing Record 25 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 3 | muisne
# Processing Record 27 of Set 3 | qaanaaq
# Processing Record 28 of Set 3 | geraldton
# Processing Record 29 of Set 3 | krini
# Processing Record 30 of Set 3 | minab
# Processing Record 31 of Set 3 | camacha
# Processing Record 32 of Set 3 | kudahuvadhoo
# Processing Record 33 of Set 3 | nara
# Processing Record 34 of Set 3 | newcastle
# Processing Record 35 of Set 3 | bathsheba
# Processing Record 36 of Set 3 | nouadhibou
# Processing Record 37 of Set 3 | buzias
# Processing Record 38 of Set 3 | busselton
# Processing Record 39 of Set 3 | schrobenhausen
# Processing Record 40 of Set 3 | ilhabela
# Processing Record 41 of Set 3 | jujuy
# City not found. Skipping...
# Processing Record 42 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 43 of Set 3 | itaituba
# Processing Record 44 of Set 3 | barrow
# Processing Record 45 of Set 3 | henties bay
# Processing Record 46 of Set 3 | asau
# Processing Record 47 of Set 3 | vung tau
# Processing Record 48 of Set 3 | zhigansk
# Processing Record 49 of Set 3 | jamestown
# Processing Record 50 of Set 3 | richards bay
# Processing Record 1 of Set 4 | tura
# Processing Record 2 of Set 4 | moree
# Processing Record 3 of Set 4 | georgetown
# Processing Record 4 of Set 4 | komsomolskiy
# Processing Record 5 of Set 4 | zhicheng
# Processing Record 6 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 4 | daru
# Processing Record 8 of Set 4 | inhambane
# Processing Record 9 of Set 4 | muhororo
# Processing Record 10 of Set 4 | yulara
# Processing Record 11 of Set 4 | vanavara
# Processing Record 12 of Set 4 | noumea
# Processing Record 13 of Set 4 | provideniya
# Processing Record 14 of Set 4 | tukrah
# Processing Record 15 of Set 4 | katsuura
# Processing Record 16 of Set 4 | yerbogachen
# Processing Record 17 of Set 4 | san patricio
# Processing Record 18 of Set 4 | pevek
# Processing Record 19 of Set 4 | bitung
# Processing Record 20 of Set 4 | paamiut
# Processing Record 21 of Set 4 | san andres
# Processing Record 22 of Set 4 | tingi
# Processing Record 23 of Set 4 | pangnirtung
# Processing Record 24 of Set 4 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 25 of Set 4 | sao joao da barra
# Processing Record 26 of Set 4 | deputatskiy
# Processing Record 27 of Set 4 | kruisfontein
# Processing Record 28 of Set 4 | hami
# Processing Record 29 of Set 4 | burica
# City not found. Skipping...
# Processing Record 30 of Set 4 | bredasdorp
# Processing Record 31 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 4 | cockburn town
# Processing Record 33 of Set 4 | moron
# Processing Record 34 of Set 4 | narsaq
# Processing Record 35 of Set 4 | esna
# Processing Record 36 of Set 4 | laguna
# Processing Record 37 of Set 4 | constitucion
# Processing Record 38 of Set 4 | santa cruz cabralia
# Processing Record 39 of Set 4 | denpasar
# Processing Record 40 of Set 4 | tual
# Processing Record 41 of Set 4 | gorontalo
# Processing Record 42 of Set 4 | kindu
# Processing Record 43 of Set 4 | gizo
# Processing Record 44 of Set 4 | amapa
# Processing Record 45 of Set 4 | akhalgori
# Processing Record 46 of Set 4 | rosetta
# Processing Record 47 of Set 4 | wazzan
# City not found. Skipping...
# Processing Record 48 of Set 4 | saskylakh
# Processing Record 49 of Set 4 | de aar
# Processing Record 50 of Set 4 | tasiilaq
# Processing Record 1 of Set 5 | san miguel
# Processing Record 2 of Set 5 | yanji
# Processing Record 3 of Set 5 | marzuq
# Processing Record 4 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 5 | staryy nadym
# Processing Record 6 of Set 5 | inuvik
# Processing Record 7 of Set 5 | broome
# Processing Record 8 of Set 5 | pusztavam
# Processing Record 9 of Set 5 | mahebourg
# Processing Record 10 of Set 5 | kununurra
# Processing Record 11 of Set 5 | oia
# Processing Record 12 of Set 5 | strezhevoy
# Processing Record 13 of Set 5 | churapcha
# Processing Record 14 of Set 5 | ukmerge
# Processing Record 15 of Set 5 | pampa
# Processing Record 16 of Set 5 | airai
# Processing Record 17 of Set 5 | bansdih
# Processing Record 18 of Set 5 | christchurch
# Processing Record 19 of Set 5 | valparaiso
# Processing Record 20 of Set 5 | gomel
# Processing Record 21 of Set 5 | carnarvon
# Processing Record 22 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 5 | esperance
# Processing Record 24 of Set 5 | tuatapere
# Processing Record 25 of Set 5 | tahoua
# Processing Record 26 of Set 5 | dakar
# Processing Record 27 of Set 5 | bandarbeyla
# Processing Record 28 of Set 5 | duxbury
# Processing Record 29 of Set 5 | port moresby
# Processing Record 30 of Set 5 | villazon
# Processing Record 31 of Set 5 | tazovskiy
# Processing Record 32 of Set 5 | presidente medici
# Processing Record 33 of Set 5 | rosarito
# Processing Record 34 of Set 5 | san cristobal
# Processing Record 35 of Set 5 | coquimbo
# Processing Record 36 of Set 5 | fukue
# Processing Record 37 of Set 5 | ho
# City not found. Skipping...
# Processing Record 38 of Set 5 | watrous
# Processing Record 39 of Set 5 | manta
# Processing Record 40 of Set 5 | goundam
# Processing Record 41 of Set 5 | isangel
# Processing Record 42 of Set 5 | norman wells
# Processing Record 43 of Set 5 | sinjar
# Processing Record 44 of Set 5 | port elizabeth
# Processing Record 45 of Set 5 | illapel
# Processing Record 46 of Set 5 | whitehorse
# Processing Record 47 of Set 5 | atlantis
# Processing Record 48 of Set 5 | golspie
# Processing Record 49 of Set 5 | kaabong
# Processing Record 50 of Set 5 | bethel
# Processing Record 1 of Set 6 | hasaki
# Processing Record 2 of Set 6 | young
# Processing Record 3 of Set 6 | chapais
# Processing Record 4 of Set 6 | chudniv
# Processing Record 5 of Set 6 | peniche
# Processing Record 6 of Set 6 | sinnamary
# Processing Record 7 of Set 6 | fort nelson
# Processing Record 8 of Set 6 | tam ky
# Processing Record 9 of Set 6 | methoni
# Processing Record 10 of Set 6 | thompson
# Processing Record 11 of Set 6 | buala
# Processing Record 12 of Set 6 | kunya
# Processing Record 13 of Set 6 | talnakh
# Processing Record 14 of Set 6 | gualeguay
# Processing Record 15 of Set 6 | beloha
# Processing Record 16 of Set 6 | manyana
# Processing Record 17 of Set 6 | souillac
# Processing Record 18 of Set 6 | san angelo
# Processing Record 19 of Set 6 | tabat
# Processing Record 20 of Set 6 | praia
# Processing Record 21 of Set 6 | bilibino
# Processing Record 22 of Set 6 | port hedland
# Processing Record 23 of Set 6 | ashqelon
# Processing Record 24 of Set 6 | ketchikan
# Processing Record 25 of Set 6 | george town
# Processing Record 26 of Set 6 | hofn
# Processing Record 27 of Set 6 | ancud
# Processing Record 28 of Set 6 | severo-yeniseyskiy
# Processing Record 29 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 6 | comodoro rivadavia
# Processing Record 31 of Set 6 | lorengau
# Processing Record 32 of Set 6 | banjar
# Processing Record 33 of Set 6 | marawi
# Processing Record 34 of Set 6 | necochea
# Processing Record 35 of Set 6 | hanko
# Processing Record 36 of Set 6 | beni suef
# Processing Record 37 of Set 6 | tres arroyos
# Processing Record 38 of Set 6 | teguise
# Processing Record 39 of Set 6 | maldonado
# Processing Record 40 of Set 6 | margate
# Processing Record 41 of Set 6 | bealanana
# Processing Record 42 of Set 6 | sur
# Processing Record 43 of Set 6 | mporokoso
# Processing Record 44 of Set 6 | chantada
# Processing Record 45 of Set 6 | port lincoln
# Processing Record 46 of Set 6 | port augusta
# Processing Record 47 of Set 6 | victoria
# Processing Record 48 of Set 6 | eydhafushi
# Processing Record 49 of Set 6 | ahipara
# Processing Record 50 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 7 | los llanos de aridane
# Processing Record 2 of Set 7 | mao
# Processing Record 3 of Set 7 | ulagan
# Processing Record 4 of Set 7 | placido de castro
# Processing Record 5 of Set 7 | tibiao
# Processing Record 6 of Set 7 | rincon
# Processing Record 7 of Set 7 | vardo
# Processing Record 8 of Set 7 | mentok
# City not found. Skipping...
# Processing Record 9 of Set 7 | port hawkesbury
# Processing Record 10 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 7 | husavik
# Processing Record 12 of Set 7 | susanville
# Processing Record 13 of Set 7 | barcelos
# Processing Record 14 of Set 7 | bagar
# Processing Record 15 of Set 7 | cremlingen
# Processing Record 16 of Set 7 | anchorage
# Processing Record 17 of Set 7 | abonnema
# Processing Record 18 of Set 7 | mackay
# Processing Record 19 of Set 7 | meadow lake
# Processing Record 20 of Set 7 | khash
# Processing Record 21 of Set 7 | longyearbyen
# Processing Record 22 of Set 7 | brae
# Processing Record 23 of Set 7 | byron bay
# Processing Record 24 of Set 7 | ballina
# Processing Record 25 of Set 7 | sisimiut
# Processing Record 26 of Set 7 | pouembout
# Processing Record 27 of Set 7 | abha
# Processing Record 28 of Set 7 | taseyevo
# Processing Record 29 of Set 7 | kjollefjord
# Processing Record 30 of Set 7 | ibra
# Processing Record 31 of Set 7 | salalah
# Processing Record 32 of Set 7 | clarence town
# Processing Record 33 of Set 7 | mumbwa
# Processing Record 34 of Set 7 | dunedin
# Processing Record 35 of Set 7 | luderitz
# Processing Record 36 of Set 7 | awjilah
# Processing Record 37 of Set 7 | saint-louis
# Processing Record 38 of Set 7 | kysyl-syr
# Processing Record 39 of Set 7 | mantua
# Processing Record 40 of Set 7 | mae sai
# Processing Record 41 of Set 7 | kinablangan
# Processing Record 42 of Set 7 | leon
# Processing Record 43 of Set 7 | chateau-gontier
# Processing Record 44 of Set 7 | lyngseidet
# Processing Record 45 of Set 7 | la quinta
# Processing Record 46 of Set 7 | talara
# Processing Record 47 of Set 7 | coahuayana
# Processing Record 48 of Set 7 | yilan
# Processing Record 49 of Set 7 | salekhard
# Processing Record 50 of Set 7 | rocha
# Processing Record 1 of Set 8 | half moon bay
# Processing Record 2 of Set 8 | phek
# Processing Record 3 of Set 8 | khilok
# Processing Record 4 of Set 8 | quang ngai
# Processing Record 5 of Set 8 | maarianhamina
# Processing Record 6 of Set 8 | goulburn
# Processing Record 7 of Set 8 | chongwe
# Processing Record 8 of Set 8 | yeletskiy
# City not found. Skipping...
# Processing Record 9 of Set 8 | canals
# Processing Record 10 of Set 8 | butka
# Processing Record 11 of Set 8 | nagua
# Processing Record 12 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 8 | thames
# Processing Record 14 of Set 8 | odweyne
# Processing Record 15 of Set 8 | jumla
# Processing Record 16 of Set 8 | kamenka
# Processing Record 17 of Set 8 | xuddur
# Processing Record 18 of Set 8 | katobu
# Processing Record 19 of Set 8 | lagoa
# Processing Record 20 of Set 8 | sao filipe
# Processing Record 21 of Set 8 | manadhoo
# Processing Record 22 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 8 | likasi
# Processing Record 24 of Set 8 | xam nua
# Processing Record 25 of Set 8 | bintulu
# Processing Record 26 of Set 8 | tall kayf
# Processing Record 27 of Set 8 | chase
# Processing Record 28 of Set 8 | monteagudo
# Processing Record 29 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 8 | hovd
# Processing Record 31 of Set 8 | suoyarvi
# Processing Record 32 of Set 8 | changli
# Processing Record 33 of Set 8 | deniliquin
# Processing Record 34 of Set 8 | nikolskoye
# Processing Record 35 of Set 8 | kalmunai
# Processing Record 36 of Set 8 | xining
# Processing Record 37 of Set 8 | russell
# Processing Record 38 of Set 8 | matara
# Processing Record 39 of Set 8 | ugoofaaru
# Processing Record 40 of Set 8 | la ronge
# Processing Record 41 of Set 8 | fleetwood
# Processing Record 42 of Set 8 | belmonte
# Processing Record 43 of Set 8 | santiago
# Processing Record 44 of Set 8 | hervey bay
# Processing Record 45 of Set 8 | buta
# Processing Record 46 of Set 8 | saint anthony
# Processing Record 47 of Set 8 | ciudad bolivar
# Processing Record 48 of Set 8 | bucerias
# Processing Record 49 of Set 8 | mooi river
# City not found. Skipping...
# Processing Record 50 of Set 8 | leningradskiy
# Processing Record 1 of Set 9 | ust-nera
# Processing Record 2 of Set 9 | nador
# Processing Record 3 of Set 9 | florence
# Processing Record 4 of Set 9 | vryburg
# Processing Record 5 of Set 9 | riviere-au-renard
# Processing Record 6 of Set 9 | budogoshch
# Processing Record 7 of Set 9 | huaiyin
# Processing Record 8 of Set 9 | dingle
# Processing Record 9 of Set 9 | suzu
# City not found. Skipping...
# Processing Record 10 of Set 9 | lipova
# Processing Record 11 of Set 9 | mitu
# Processing Record 12 of Set 9 | balotra
# Processing Record 13 of Set 9 | lewistown
# Processing Record 14 of Set 9 | port blair
# Processing Record 15 of Set 9 | diego de almagro
# Processing Record 16 of Set 9 | sirkali
# City not found. Skipping...
# Processing Record 17 of Set 9 | mattawa
# Processing Record 18 of Set 9 | tsuyama
# Processing Record 19 of Set 9 | gleisdorf
# Processing Record 20 of Set 9 | neuquen
# Processing Record 21 of Set 9 | kargasok
# Processing Record 22 of Set 9 | dhidhdhoo
# Processing Record 23 of Set 9 | madang
# Processing Record 24 of Set 9 | road town
# Processing Record 25 of Set 9 | baghdad
# Processing Record 26 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 27 of Set 9 | gouyave
# Processing Record 28 of Set 9 | haines junction
# Processing Record 29 of Set 9 | harboore
# Processing Record 30 of Set 9 | kardla
# Processing Record 31 of Set 9 | kaitangata
# Processing Record 32 of Set 9 | mocuba
# Processing Record 33 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 34 of Set 9 | metro
# Processing Record 35 of Set 9 | lavrentiya
# Processing Record 36 of Set 9 | zyryanka
# Processing Record 37 of Set 9 | prince rupert
# Processing Record 38 of Set 9 | baoding
# Processing Record 39 of Set 9 | sambek
# Processing Record 40 of Set 9 | rio grande
# Processing Record 41 of Set 9 | anadyr
# Processing Record 42 of Set 9 | vestmanna
# Processing Record 43 of Set 9 | nioro
# Processing Record 44 of Set 9 | khuzhir
# Processing Record 45 of Set 9 | nome
# Processing Record 46 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 47 of Set 9 | slavyanka
# Processing Record 48 of Set 9 | qui nhon
# Processing Record 49 of Set 9 | noshiro
# Processing Record 50 of Set 9 | madrid
# Processing Record 1 of Set 10 | yabelo
# Processing Record 2 of Set 10 | linxia
# Processing Record 3 of Set 10 | usinsk
# Processing Record 4 of Set 10 | sechura
# Processing Record 5 of Set 10 | krasnoselkup
# Processing Record 6 of Set 10 | sitio novo do tocantins
# Processing Record 7 of Set 10 | yelan-kolenovskiy
# Processing Record 8 of Set 10 | misratah
# Processing Record 9 of Set 10 | oktyabrskiy
# Processing Record 10 of Set 10 | praia da vitoria
# Processing Record 11 of Set 10 | puerto madero
# Processing Record 12 of Set 10 | koluszki
# Processing Record 13 of Set 10 | kaka
# Processing Record 14 of Set 10 | vostok
# Processing Record 15 of Set 10 | grindavik
# Processing Record 16 of Set 10 | sola
# Processing Record 17 of Set 10 | mosetse
# Processing Record 18 of Set 10 | jian
# Processing Record 19 of Set 10 | stoyba
# City not found. Skipping...
# Processing Record 20 of Set 10 | biak
# Processing Record 21 of Set 10 | pringsewu
# Processing Record 22 of Set 10 | northam
# Processing Record 23 of Set 10 | one hundred mile house
# City not found. Skipping...
# Processing Record 24 of Set 10 | acarau
# Processing Record 25 of Set 10 | seymchan
# Processing Record 26 of Set 10 | tiksi
# Processing Record 27 of Set 10 | paratebueno
# Processing Record 28 of Set 10 | novyy chirkey
# Processing Record 29 of Set 10 | kamiiso
# Processing Record 30 of Set 10 | saint-leu
# Processing Record 31 of Set 10 | zhireken
# Processing Record 32 of Set 10 | mayo
# Processing Record 33 of Set 10 | charagua
# Processing Record 34 of Set 10 | rio de loba
# Processing Record 35 of Set 10 | grand gaube
# Processing Record 36 of Set 10 | laurel
# Processing Record 37 of Set 10 | kampong chhnang
# Processing Record 38 of Set 10 | kolvereid
# Processing Record 39 of Set 10 | landeck
# Processing Record 40 of Set 10 | surt
# Processing Record 41 of Set 10 | bor
# Processing Record 42 of Set 10 | brigham city
# Processing Record 43 of Set 10 | eureka
# Processing Record 44 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 45 of Set 10 | torbay
# Processing Record 46 of Set 10 | umuahia
# Processing Record 47 of Set 10 | kolyvan
# Processing Record 48 of Set 10 | clearlake
# Processing Record 49 of Set 10 | letnik
# Processing Record 50 of Set 10 | conde
# Processing Record 1 of Set 11 | santa lucia
# Processing Record 2 of Set 11 | port hardy
# Processing Record 3 of Set 11 | dibaya
# City not found. Skipping...
# Processing Record 4 of Set 11 | gigmoto
# Processing Record 5 of Set 11 | labrea
# Processing Record 6 of Set 11 | floro
# Processing Record 7 of Set 11 | melfort
# Processing Record 8 of Set 11 | bonthe
# Processing Record 9 of Set 11 | saint stephen
# Processing Record 10 of Set 11 | caramay
# Processing Record 11 of Set 11 | stavelot
# Processing Record 12 of Set 11 | opochka
# Processing Record 13 of Set 11 | aiud
# Processing Record 14 of Set 11 | sawtell
# Processing Record 15 of Set 11 | winnemucca
# Processing Record 16 of Set 11 | foumban
# Processing Record 17 of Set 11 | vanderhoof
# Processing Record 18 of Set 11 | santa marinella
# Processing Record 19 of Set 11 | tiznit
# Processing Record 20 of Set 11 | zunyi
# Processing Record 21 of Set 11 | pozo colorado
# Processing Record 22 of Set 11 | adrar
# Processing Record 23 of Set 11 | wellington
# Processing Record 24 of Set 11 | sabzevar
# Processing Record 25 of Set 11 | monrovia
# Processing Record 26 of Set 11 | bajo baudo
# City not found. Skipping...
# Processing Record 27 of Set 11 | bac giang
# Processing Record 28 of Set 11 | yinchuan
# Processing Record 29 of Set 11 | durban
# Processing Record 30 of Set 11 | fairbanks
# Processing Record 31 of Set 11 | deep river
# Processing Record 32 of Set 11 | atambua
# Processing Record 33 of Set 11 | dubbo
# Processing Record 34 of Set 11 | bakel
# Processing Record 35 of Set 11 | kouqian
# Processing Record 36 of Set 11 | azare
# Processing Record 37 of Set 11 | alta floresta
# Processing Record 38 of Set 11 | port arthur
# Processing Record 39 of Set 11 | oranjemund
# Processing Record 40 of Set 11 | marshalltown
# Processing Record 41 of Set 11 | kolondieba
# Processing Record 42 of Set 11 | craigieburn
# Processing Record 43 of Set 11 | phalaborwa
# Processing Record 44 of Set 11 | barranca
# Processing Record 45 of Set 11 | jeremie
# Processing Record 46 of Set 11 | moose factory
# Processing Record 47 of Set 11 | aklavik
# Processing Record 48 of Set 11 | mergui
# City not found. Skipping...
# Processing Record 49 of Set 11 | prince george
# Processing Record 50 of Set 11 | coos bay
# Processing Record 1 of Set 12 | vagur
# Processing Record 2 of Set 12 | punta cardon
# Processing Record 3 of Set 12 | trelew
# Processing Record 4 of Set 12 | dimbokro
# Processing Record 5 of Set 12 | linchuan
# City not found. Skipping...
# Processing Record 6 of Set 12 | mus
# Processing Record 7 of Set 12 | caucaia
# Processing Record 8 of Set 12 | saint-augustin
# Processing Record 9 of Set 12 | changji
# Processing Record 10 of Set 12 | elumalai
# Processing Record 11 of Set 12 | chicama
# Processing Record 12 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 13 of Set 12 | teguldet
# Processing Record 14 of Set 12 | burgeo
# Processing Record 15 of Set 12 | vanimo
# Processing Record 16 of Set 12 | durazno
# Processing Record 17 of Set 12 | antofagasta
# Processing Record 18 of Set 12 | jimo
# Processing Record 19 of Set 12 | santa cruz
# Processing Record 20 of Set 12 | zabid
# Processing Record 21 of Set 12 | ossora
# Processing Record 22 of Set 12 | wailuku
# Processing Record 23 of Set 12 | higuey
# City not found. Skipping...
# Processing Record 24 of Set 12 | osmena
# Processing Record 25 of Set 12 | riga
# Processing Record 26 of Set 12 | semnan
# Processing Record 27 of Set 12 | algiers
# Processing Record 28 of Set 12 | arcachon
# Processing Record 29 of Set 12 | tautira
# Processing Record 30 of Set 12 | samarai
# Processing Record 31 of Set 12 | novopokrovka
# Processing Record 32 of Set 12 | cairns
# Processing Record 33 of Set 12 | galbshtadt
# Processing Record 34 of Set 12 | acurenam
# Processing Record 35 of Set 12 | cuamba
# Processing Record 36 of Set 12 | bolshaya orlovka
# City not found. Skipping...
# Processing Record 37 of Set 12 | gornyy
# Processing Record 38 of Set 12 | mayna
# Processing Record 39 of Set 12 | puerto varas
# Processing Record 40 of Set 12 | gollere
# City not found. Skipping...
# Processing Record 41 of Set 12 | egvekinot
# Processing Record 42 of Set 12 | aykhal
# Processing Record 43 of Set 12 | kasempa
# Processing Record 44 of Set 12 | wanning
# Processing Record 45 of Set 12 | freetown
# Processing Record 46 of Set 12 | burnie
# Processing Record 47 of Set 12 | najran
# Processing Record 48 of Set 12 | meybod
# Processing Record 49 of Set 12 | roebourne
# Processing Record 50 of Set 12 | zeerust
# Processing Record 1 of Set 13 | hambantota
# Processing Record 2 of Set 13 | kavieng
# Processing Record 3 of Set 13 | jackson
# Processing Record 4 of Set 13 | verkhoyansk
# Processing Record 5 of Set 13 | te anau
# Processing Record 6 of Set 13 | fortuna
# Processing Record 7 of Set 13 | cayenne
# Processing Record 8 of Set 13 | tiruvottiyur
# City not found. Skipping...
# Processing Record 9 of Set 13 | puerto ayacucho
# Processing Record 10 of Set 13 | maragogi
# Processing Record 11 of Set 13 | puro
# Processing Record 12 of Set 13 | impfondo
# Processing Record 13 of Set 13 | carros
# Processing Record 14 of Set 13 | sobolevo
# Processing Record 15 of Set 13 | mogadishu
# Processing Record 16 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 17 of Set 13 | ostrovnoy
# Processing Record 18 of Set 13 | namatanai
# Processing Record 19 of Set 13 | maksatikha
# Processing Record 20 of Set 13 | conway
# Processing Record 21 of Set 13 | bhawana
# Processing Record 22 of Set 13 | rolim de moura
# City not found. Skipping...
# Processing Record 23 of Set 13 | turukhansk
# Processing Record 24 of Set 13 | yerkoy
# Processing Record 25 of Set 13 | valkeala
# Processing Record 26 of Set 13 | aksu
# Processing Record 27 of Set 13 | ulaangom
# Processing Record 28 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 29 of Set 13 | alice springs
# Processing Record 30 of Set 13 | mega
# Processing Record 31 of Set 13 | san carlos de bariloche
# Processing Record 32 of Set 13 | morro bay
# Processing Record 33 of Set 13 | berlevag
# Processing Record 34 of Set 13 | carutapera
# Processing Record 35 of Set 13 | maketu
# Processing Record 36 of Set 13 | shubarkuduk
# Processing Record 37 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 38 of Set 13 | agropoli
# Processing Record 39 of Set 13 | mentakab
# Processing Record 40 of Set 13 | araci
# Processing Record 41 of Set 13 | yar-sale
# Processing Record 42 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 43 of Set 13 | rock sound
# Processing Record 44 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 45 of Set 13 | hereford
# Processing Record 46 of Set 13 | brigantine
# Processing Record 47 of Set 13 | saint george
# Processing Record 48 of Set 13 | goderich
# Processing Record 49 of Set 13 | pakokku
# Processing Record 50 of Set 13 | lanzhou
# Processing Record 1 of Set 14 | homa bay
# Processing Record 2 of Set 14 | verkhnevilyuysk
# Processing Record 3 of Set 14 | coxim
# Processing Record 4 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 14 | manokwari
# Processing Record 6 of Set 14 | srednekolymsk
# Processing Record 7 of Set 14 | iqaluit
# Processing Record 8 of Set 14 | zelenogorskiy
# Processing Record 9 of Set 14 | kirkwall
# Processing Record 10 of Set 14 | merauke
# Processing Record 11 of Set 14 | auki
# Processing Record 12 of Set 14 | darnah
# Processing Record 13 of Set 14 | gohpur
# Processing Record 14 of Set 14 | krasnaya gorka
# Processing Record 15 of Set 14 | williamsburg
# Processing Record 16 of Set 14 | labuhan
# Processing Record 17 of Set 14 | bilma
# Processing Record 18 of Set 14 | oda
# Processing Record 19 of Set 14 | seneffe
# Processing Record 20 of Set 14 | acajutla
# Processing Record 21 of Set 14 | canberra
# Processing Record 22 of Set 14 | mount isa
# Processing Record 23 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 24 of Set 14 | san lorenzo
# Processing Record 25 of Set 14 | kilindoni
# Processing Record 26 of Set 14 | bonavista
# Processing Record 27 of Set 14 | slupsk
# Processing Record 28 of Set 14 | longfeng
# Processing Record 29 of Set 14 | silifke
# Processing Record 30 of Set 14 | galesong
# Processing Record 31 of Set 14 | vagay
# Processing Record 32 of Set 14 | asopos
# Processing Record 33 of Set 14 | bulgan
# Processing Record 34 of Set 14 | wana
# Processing Record 35 of Set 14 | xuzhou
# Processing Record 36 of Set 14 | muroto
# Processing Record 37 of Set 14 | mitsamiouli
# Processing Record 38 of Set 14 | ust-kuyga
# Processing Record 39 of Set 14 | birjand
# Processing Record 40 of Set 14 | nyurba
# Processing Record 41 of Set 14 | shakawe
# Processing Record 42 of Set 14 | arrecife
# Processing Record 43 of Set 14 | qabis
# City not found. Skipping...
# Processing Record 44 of Set 14 | erie
# Processing Record 45 of Set 14 | chingirlau
# Processing Record 46 of Set 14 | robertsport
# Processing Record 47 of Set 14 | garm
# City not found. Skipping...
# Processing Record 48 of Set 14 | slave lake
# Processing Record 49 of Set 14 | okha
# Processing Record 50 of Set 14 | arroio grande
# Processing Record 1 of Set 15 | itiuba
# Processing Record 2 of Set 15 | boone
# Processing Record 3 of Set 15 | alginet
# Processing Record 4 of Set 15 | dien bien
# City not found. Skipping...
# Processing Record 5 of Set 15 | tilichiki
# Processing Record 6 of Set 15 | douentza
# Processing Record 7 of Set 15 | ardistan
# City not found. Skipping...
# Processing Record 8 of Set 15 | miles city
# Processing Record 9 of Set 15 | kaohsiung
# Processing Record 10 of Set 15 | albina
# Processing Record 11 of Set 15 | makow mazowiecki
# Processing Record 12 of Set 15 | port victoria
# Processing Record 13 of Set 15 | portland
# Processing Record 14 of Set 15 | jinchang
# Processing Record 15 of Set 15 | poum
# Processing Record 16 of Set 15 | skagastrond
# City not found. Skipping...
# Processing Record 17 of Set 15 | kathmandu
# Processing Record 18 of Set 15 | olafsvik
# Processing Record 19 of Set 15 | aktash
# Processing Record 20 of Set 15 | buritis
# Processing Record 21 of Set 15 | tamarindo
# Processing Record 22 of Set 15 | milingimbi
# City not found. Skipping...
# Processing Record 23 of Set 15 | solsvik
# City not found. Skipping...
# Processing Record 24 of Set 15 | yafran
# Processing Record 25 of Set 15 | sorong
# Processing Record 26 of Set 15 | ialibu
# Processing Record 27 of Set 15 | caxito
# Processing Record 28 of Set 15 | boguchany
# Processing Record 29 of Set 15 | zhanaozen
# Processing Record 30 of Set 15 | mombetsu
# Processing Record 31 of Set 15 | djambala
# Processing Record 32 of Set 15 | hoquiam
# Processing Record 33 of Set 15 | pitsunda
# Processing Record 34 of Set 15 | ulaanbaatar
# Processing Record 35 of Set 15 | sabaudia
# Processing Record 36 of Set 15 | sawakin
# Processing Record 37 of Set 15 | araouane
# Processing Record 38 of Set 15 | tezu
# Processing Record 39 of Set 15 | akhmim
# Processing Record 40 of Set 15 | taltal
# Processing Record 41 of Set 15 | kon tum
# Processing Record 42 of Set 15 | leh
# Processing Record 43 of Set 15 | jacareacanga
# Processing Record 44 of Set 15 | belaya gora
# Processing Record 45 of Set 15 | hailar
# Processing Record 46 of Set 15 | coshocton
# Processing Record 47 of Set 15 | khipro
# Processing Record 48 of Set 15 | nemuro
# Processing Record 49 of Set 15 | constantine
# Processing Record 50 of Set 15 | althofen
# Processing Record 1 of Set 16 | karaul
# City not found. Skipping...
# Processing Record 2 of Set 16 | puerto quijarro
# Processing Record 3 of Set 16 | manakara
# Processing Record 4 of Set 16 | summerville
# Processing Record 5 of Set 16 | kovdor
# Processing Record 6 of Set 16 | hualmay
# Processing Record 7 of Set 16 | ulladulla
# Processing Record 8 of Set 16 | chiredzi
# Processing Record 9 of Set 16 | weligama
# Processing Record 10 of Set 16 | makakilo city
# Processing Record 11 of Set 16 | raton
# Processing Record 12 of Set 16 | vikindu
# Processing Record 13 of Set 16 | roald
# Processing Record 14 of Set 16 | jiazi
# Processing Record 15 of Set 16 | portoferraio
# Processing Record 16 of Set 16 | troitsko-pechorsk
# Processing Record 17 of Set 16 | alappuzha
# Processing Record 18 of Set 16 | namibe
# Processing Record 19 of Set 16 | matay
# Processing Record 20 of Set 16 | lodja
# Processing Record 21 of Set 16 | abeche
# Processing Record 22 of Set 16 | gunjur
# Processing Record 23 of Set 16 | murdochville
# Processing Record 24 of Set 16 | isla vista
# Processing Record 25 of Set 16 | copiapo
# Processing Record 26 of Set 16 | calvinia
# Processing Record 27 of Set 16 | bandar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Nouakchott      MR  18.0858  -15.9785     73.35        29         100
# 1          Yaan      NG   7.3833    8.5667     75.74        22          25
# 2        Potosi      BO -19.5836  -65.7531     53.11        35          43
# 3  Punta Arenas      CL -53.1500  -70.9167     42.91        65          75
# 4       Kazerun      IR  29.6195   51.6541     53.94        25           6
# 5      Hermanus      ZA -34.4187   19.2345     61.90        89          91
# 6   New Norfolk      AU -42.7826  147.0587     77.67        28           0
# 7        Atuona      PF  -9.8000 -139.0333     78.98        80          83
# 8        Chokwe      MZ -24.5333   32.9833     79.18        71          92
# 9        Mehamn      NO  71.0357   27.8492     26.55        94          99
#
#    Wind Speed Current Description
# 0       13.51     overcast clouds
# 1        4.52    scattered clouds
# 2        2.48    scattered clouds
# 3       21.85       broken clouds
# 4        4.03           clear sky
# 5        4.92     overcast clouds
# 6        1.99           clear sky
# 7       17.43          light rain
# 8        2.04     overcast clouds
# 9       11.63          light snow

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
# Create the output file (CSV).
output_data_file = "./WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
